# %%
import requests
import os
from datetime import datetime
from dotenv import load_dotenv
from pathlib import Path
import numpy as np
import calendar

import pandas as pd 

dotenv_path = Path('/root/workspace/.env')
load_dotenv(dotenv_path=dotenv_path)

ELASTIC_PORT = os.environ.get("ELASTIC_PORT", None)
ELASTIC_USERNAME = os.environ.get("ELASTIC_USERNAME", None)
ELASTIC_PASSWORD = os.environ.get("ELASTIC_PASSWORD", None)

assert ELASTIC_PORT is not None, "ELASTIC_PORT is not set"
assert ELASTIC_USERNAME is not None, "ELASTIC_USERNAME is not set"
assert ELASTIC_PASSWORD is not None, "ELASTIC_PASSWORD is not set"

config = {
    # Global config
    "HOST": "0.0.0.0",
    "PORT": ELASTIC_PORT,
    "USERNAME": ELASTIC_USERNAME,
    "PASSWORD": ELASTIC_PASSWORD,
    "INDEX": None,
    "RETURN_SIZE": 10,
    "CACHE_DIR": ".cache/",
    "DIMENSION": 2,
}

# %% [markdown]
# ## Prepapre DB

# %%
import pandas as pd 
from tqdm import tqdm 
df = pd.read_csv('/root/workspace/data/meta/lsc23.csv')
# Out:
# /tmp/ipykernel_3019858/505699392.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/root/workspace/data/meta/lsc23.csv')

# %%
# fill nan description with empty string
df = df.fillna('')
df.describe()
# Out:
#              new_lat        new_lng  movement_prob
# count  723329.000000  723329.000000  723329.000000
# mean       50.232795       2.246000       0.869080
# std        10.934981      28.858598       0.169180
# min       -37.824879     -75.702031       0.000000
# 25%        53.385440      -6.257253       0.792520
# 50%        53.386041      -6.174619       0.956895
# 75%        53.389969      -6.145784       0.991074
# max        60.390785     144.953833       0.999939

# %%
df.head()
# Out:
#        minute_id  stop   new_lat  new_lng semantic_name foursquare_id  \
# 0  20190101_1037  True  53.38998 -6.14576          HOME
# 1  20190101_1037  True  53.38998 -6.14576          HOME
# 2  20190101_1038  True  53.38998 -6.14576          HOME
# 3  20190101_1038  True  53.38998 -6.14576          HOME
# 4  20190101_1039  True  53.38998 -6.14576          HOME
#
#   original_name categories parent movement  movement_prob  \
# 0                                   Inside       0.981373
# 1                                   Inside       0.997463
# 2                                   Inside       0.875969
# 3                                   Inside       0.998937
# 4                                   Inside       0.756499
#
#                         city  country   new_timezone                index  \
# 0  Dublin, Ireland, Leinster  Ireland  Europe/Dublin  20190101_103717_000
# 1  Dublin, Ireland, Leinster  Ireland  Europe/Dublin  20190101_103749_000
# 2  Dublin, Ireland, Leinster  Ireland  Europe/Dublin  20190101_103821_000
# 3  Dublin, Ireland, Leinster  Ireland  Europe/Dublin  20190101_103853_000
# 4  Dublin, Ireland, Leinster  Ireland  Europe/Dublin  20190101_103925_000
#
#                    ImageID                                  Tags OCR  \
# 0  20190101_103717_000.jpg                                indoor
# 1  20190101_103749_000.jpg            wall,indoor,room,furniture
# 2  20190101_103821_000.jpg                       building,window
# 3  20190101_103853_000.jpg  indoor,wall,person,counter,cluttered
# 4  20190101_103925_000.jpg                           indoor,wall
#
#                                              Caption CaptionScore
# 0                            a window with a curtain     0.367844
# 1                   a room with a shelf and a mirror     0.277621
# 2                 a view of a building from a window     0.349112
# 3                              a person in a kitchen     0.491968
# 4  a black rectangular object with a white object...      0.33464

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# drop if index starts with 2000 
df = df[~df['index'].str.startswith('2000')]

# %%
df.semantic_name.describe()
# Out:
# count                           723329
# unique                             734
# top       Dublin City University (DCU)
# freq                            226825
# Name: semantic_name, dtype: object

# %%
df.new_lat.isna().sum()
# Out:
# 0

# %%
df.semantic_name.value_counts()
# Out:
# semantic_name
# Dublin City University (DCU)              226825
# HOME                                      193201
# Car                                        93468
# Charm Hand & Foot Spa                      29974
# Airplane                                   16117
#                                            ...
# Prada                                          1
# Bonjour Resto - Beefsteak Hai Ba Trung         1
# Boomerang Nightclub                            1
# Windsor Avenue                                 1
# Glendalough Upper Lake Car Park                1
# Name: count, Length: 734, dtype: int64

# %%
df.semantic_name.unique()
# Out:
# array(['HOME', 'Car', 'Charm Hand & Foot Spa', 'TOP Oil',
#        'Brown Thomas Car Park', 'Brown Thomas', 'Walking Outside',
#        'Dubray Books', "Stephen's Green Shopping Centre",
#        'Broadridge Ireland', "Eddie Rocket's",
#        'Killashee House Hotel & Villa Spa', 'Kildare Village',
#        'Watch Station International Kildare', "O'Connors",
#        'Naas Retail Park', 'Conlans BMW - Kildare', 'GreenIT', 'B&Q Naas',
#        'Kingfisher Indian Restaurant', 'Man Importers Ireland',
#        'SuperValu', 'Dublin City University (DCU)', 'Get Fresh',
#        'Public Transport', 'Donaghmede Shopping Centre',
#        'DCU School of Computing', 'Dublin Airport (DUB)', 'Airplane',
#        'Frankfurt Airport (FRA) (Frankfurt Airport)',
#        'Thessaloniki International Airport Macedonia', 'Gregalef Loft',
#        'Eat Skaste', 'MD Medical Biometric', 'Mediterranean Palace Hotel',
#        'Baron Hirsch Hall', 'The Grocery Store of Thessaloniki',
#        'Mallioras Kontosouvli', 'Cycling', 'Zeus Conference Rooms',
#        'Law Office Pavlos Kesoglou, Asimina Mangola and Associates',
#        'The Blue Cup | Creative Bar', 'IQOS Papastratos',
#        'Aristotelous Square', 'Pavlos Papadopoulos Dentistry',
#        'Technical Office Engineering - Counseling',
#        'The Blue Cup (The Blue Cup & Speakeasy)', 'Unknown Place',
#        'Frankfurt Airport', 'Centra', 'Lidl', 'Sounds Around', 'Tesco',
#        'Clontarf Castle Hotel', 'Costa Coffee', 'Waxbrothers.ie',
#        'Bayside Square Car Park', 'Harmonstown Dart Station', 'Inside',
#        'Homebase', 'Coombe Women & Infants University Hospital', 'Aldi',
#        'Oriental Pantry Supermarket', 'The Helix', 'Circle K',
#        'Musgeaves Marketplace', 'Calor Gas', 'Corpus Christi',
#        'Seafront Raheny-Sutton', 'The Morgan Hotel', 'The Westin Dublin',
#        'The Bank on College Green', 'Vintage Cocktail Club',
#        'The Quays Irish Restaurant', 'Park Rite Christchurch Car Park',
#        'Power City', 'Cedar Lounge The', 'Omni Shopping Centre',
#        'Penneys', 'Musgrave Marketplace', 'Mr. Dinh', 'Tesco Extra',
#        'Starbucks', 'Beshoffs Of Howth', "Woodie's DIY", 'Dunnes Stores',
#        'Il Fornaio - Italian Restaurant & Bakery', 'Howth Edge',
#        'Newbridge Chinese Take Away', 'DCU Business School',
#        'Park Rite Fleet St Car Park', "Mary's", 'Trinity College Dublin',
#        'Carpetright', 'Pavilions Shopping Centre', 'Spar', 'Craft',
#        'Donnycarney Church', 'Octopussy Seafood Tapas',
#        'The Galway Plaza', 'National University of Ireland Galway',
#        'The Ardilaun Hotel', 'Istanbul Ataturk Airport', 'The Tresor',
#        'Vincom Center', 'Park Hyatt Saigon', 'Monte Carlo Saigon',
#        'Drunken Duck', 'Bitexco Financial Tower', 'Vietcombank',
#        'Banh Mi 24', 'Spencer Outlet Centre', 'Southern Cross Station',
#        'Collins Square', 'Melbourne Convention and Exhibition Centre',
#        'Watergardens', 'Switch Cafe', 'THY OCC Building',
#        'Shamrock Hand and Foot Spa', 'Rathfarnham Shopping Centre',
#        'Rathfarnham Gate', 'Hot Bubble Cafe', 'Arisu',
#        'Four Star Pizza Raheny', 'JoJo Maman Bébé',
#        'Huckletree Dublin D2', 'Musgrave', 'Fuel... Fit Food',
#        'The Ceeders', 'Topaz Donaghmede', 'IKEA', 'Gullivers Retail Park',
#        'Coderdojo DCU', 'Jurys Inn Parnell Street', 'Bun Cha',
#        'SO Nutrition', 'Ilac Centre Carpark', 'Slender Health Beauty',
#        'Gate 206', 'Garden Terrace Bar Terminal 1 Dublin Air Port',
#        'Bakirkoy District Governorate', 'Suvarnabhumi Airport',
#        'The Station Condo Building B', 'Cherry Yentafo', 'Ailati Resto',
#        'Fitzgeralds Irish Pub', 'Nana Plaza', 'Burger King',
#        'The Station Condo Building A', 'KU Avenue',
#        'Kasetsart University', 'Chiap Hong Seng', 'BTS Saphan Taksin',
#        'Charoen Krung 65',
#        'Hotel Indigo Bangkok Wireless Road, an IHG Hotel',
#        'Thammasat University', 'Bangkok Bank', 'Chao Phya Tower',
#        'Mazzaro Boutique & Restaurant', 'Chulalongkorn University',
#        'Chamchuri Square', 'Faculty of Engineering',
#        'Red Planet Bangkok Surawong', 'The Grand Sathorn',
#        'Eastin Grand Hotel Sathorn', 'Mode Sathorn Hotel',
#        'Asiatique The Riverfront', 'BKK Original', 'Gate 309',
#        'Kolbaslar Automotive', 'Howth Market', 'Avoca Handweavers',
#        'Glendalough Upper Lake Car Park', 'Monastic City Gateway',
#        'Radisson Blu Royal Hotel', 'Gourmet Burger Kitchen',
#        'Ulster Bank', 'Dundrum Town Centre', 'Postgraduate Room Q159 DCU',
#        'Harmonstown', 'The Bloody Stream',
#        'Bayside Church Of The Resurrection - Sutton',
#        'Maldron Hotel Tallaght', 'Clare Hall Shopping Centre',
#        'Airside Retail Park', "McDonald's", 'VHI Swiftcare Clinic Swords',
#        'Cois Bá Family Practice', 'The Red Stables', 'Picasso Restaurant',
#        'Irish Independent', 'Pho Ta', 'Eircom', 'The Sheds',
#        'The Mint Cottage', "DCU St. Patrick's Campus", 'DCU Restaurant',
#        'Liffey Valley Shopping Centre',
#        'IDA Clonshaugh Business & Technology Park.',
#        "Butler's Chocolate Factory", 'Copenhagen Airport',
#        'SAS Gold Lounge', 'Media City Bergen', 'Spaces Vaskerelven',
#        'Hectors Hybel', 'Scandic Byparken', 'Bergen Airport, Flesland',
#        'Eventyr Lounge', 'Copenhagen Airport Kastrup', 'Quickfitness',
#        'Bellmayne', 'The Fleet Street Hotel',
#        'Citylink - Dublin To Galway Non-Stop', "The Ha'Penny Bridge",
#        'The Temple Bar', 'Street 66', 'The Beer Temple',
#        'Thunders Bakery', 'Newpark Hotel', 'Left Bank', 'Kilkenny Castle',
#        'Kilkenny Hibernian Hotel', 'EBS Kilkenny',
#        'Newpark Hotel Kilkenny with Escape Health Club & Spa',
#        'Kilkenny Design Centre', '€uro Giant',
#        'Kilkenny Design Workshops', 'Argos',
#        'Market Cross Shopping Centre', "King's Shoes",
#        "St Mary's Cathedral", 'Camile Thai', 'Kitty Kiernans',
#        'Joe Duffy Volvo', 'Beaumont Hospital',
#        'Pattaya Thai Chinese Restaurant',
#        'Pattaya Thai & Chinese Restaurant', 'Finnstown Medical Centre',
#        'Stillorgan Village', 'Howth Junction Cottages',
#        'Northside Shopping Centre', 'The Marker Hotel Dublin',
#        'Homebase - Dublin Santry', 'Istanbul Airport',
#        'Tan Son Nhat International Airport', 'Pastel Inn Saigon Hotel',
#        'Notre Dame Cathedral Soup', 'Highlands Dinh Doc Lap',
#        'Marie Curie High School', 'Vietcombank - PGD so 10',
#        'Hard Rock Cafe Ho Chi Minh City', 'KUMHO ASIANA PLAZA cafe',
#        'Independence Palace', 'UEL Training Department',
#        'Cay Dua Restaurant', 'The Rex Arcade',
#        'Liberty Central Saigon Citypoint', 'Saigon Centre',
#        'Vit Gay Restaurant', 'Vietjet Air Check-in Counter',
#        'VATC SleepPod T2', 'Noi Bai International Airport',
#        'Highlands Coffee', 'Embassy of Ireland in Vietnam',
#        'Ha Noi children park', 'Hoan Kiem Lake', 'Security Check Hall E',
#        'Tous Les Jours', 'Bonjour Resto - Beefsteak Hai Ba Trung',
#        'Hoi Ngo Restaurant', 'Liberty Central Saigon Citypoint Hotel',
#        'Ton Duc Thang University', '7-Eleven', 'Doi Dep Cafe',
#        'Ho Chi Minh City University Of Science', 'NOWZONE Fashion Mall',
#        'Sportsman', 'Bhiraj Tower at Sathon', 'Emquartier', 'ICONSIAM',
#        'JD Sport', 'Siam Takashimaya', 'Khlong San Market', 'Iconsiam',
#        'Robinson', 'Thammasat Hospital', 'KMUTT Library',
#        'The Parque Condo', "McDonald's & McCafé", 'Kance Bangkok Cafe',
#        'Mahidol University', 'Pat Stadium', 'All Seasons Place',
#        'TotalEnergies', '', 'AIB', 'Le Petit Parisien',
#        'Butlers Chocolate Café', 'Music Maker', 'Perky’s Delicious',
#        'Ilac Centre', 'Dealz', 'Insomnia', 'Howth Harbour',
#        'Steven An Nails & Spa', 'One Cumberland Place',
#        'Churchtown Stores', "Dublin City University St. Patrick's Campus",
#        'Musgrave MarketPlace', "Kane & McCartney's SuperValu",
#        'Il Fornaio', 'Beshoff Bros',
#        'Ottawa Macdonald-Cartier International Airport (YOW)',
#        'Montreal-Pierre Elliott Trudeau International Airport', 'Gate 65',
#        'Dorval Tunnel', 'Lugano Railway Station', 'La Tinera',
#        'Piazza della Riforma', 'Coop', 'Hotel Walter au Lac',
#        'USI Universita della Svizzera italiana', 'Vecchio Torchio',
#        'Zurich Main Station', 'Townhouse Boutique Hotel',
#        'Zurich Airport', 'Red Cow Moran Hotel',
#        'The Cock and Bull Coolock', 'La Gustosa', 'The Kilbronx',
#        'Costa Coffee Northwood', 'The Waggy Tail Tea Rooms',
#        'Portmarnock Hotel & Golf Links', 'Euro Car Parts',
#        'Smithfield Apartments Dublin', 'Smithfield Square', 'Fresh',
#        'Denis Mahony', 'The Street - DCU',
#        "The Car Park That Isn't Really A Car Park", 'Order of Malta',
#        'Peter Mark', "Gino's Gelato", 'All Hallows College',
#        'MAC Cosmetics Brown Thomas', 'Ladurée Dublin',
#        'Bonsai Bar Dublin', 'B2 Hairdressing Salon',
#        'IMC Santry Omni Park, Santry, Dublin, Ireland Dublin 9',
#        'Crossroads St Annes & Dollymount', 'Dole',
#        'Radisson Blu Royal Restaurant', 'Powerscourt Centre', 'Reiss',
#        'Gretstones Stores', 'Woodenbridge Hotel and Lodge',
#        "Hunter's Rest", 'LinkedIn EMEA HQ', 'Veritas Technologies',
#        'Homestore + More', 'Radisson Blu Hotel & Spa, Sligo',
#        'Lissadell House', 'Clayton Hotel Sligo',
#        'Sligo Johnston Court Shopping Centre', 'Radisson Blu Hotel & Spa',
#        'Classiebawn', 'Golden Wok', 'Dundrum Village Centre', 'Essence',
#        'Bank of Ireland', 'EZliving', 'Harvey Norman',
#        'Irish Wheelchair Association Gym', 'Central Remedial Clinic',
#        'Great Hall', 'The Marine Hotel', 'Terenure College', 'Vodafone',
#        'The Templeogue Inn (The Morgue)', 'Mount Jerome Cemetery',
#        'B&R Howard', 'The Church', "Nando's",
#        'Smyths Toys - Jervis Street', 'Equipet Coolock', 'Mini Storage',
#        'NCT Centre', 'Savoy Cinema', 'Sutton Park', 'Louis Copeland',
#        'Eatokyo', 'The Auld Dubliner', 'Roast',
#        "The Ha'penny (Liffey) Bridge", 'Avoca Cafe', 'Malahide Beach',
#        'Sacred Heart Residence', 'Costcutter', 'Dublin City Bikram Yoga',
#        'The Market Bar', "George's Street Arcade", 'Starbucks Howth',
#        'Carine - Waxing', 'Raheny Library',
#        'Mercy Beaumont Secondary School', 'Kilbarrack Road',
#        'Glaslyn Apartments', 'Hession Hairdressing', 'Elm Mount Court',
#        'Ikea', '"The Shelbourne Dublin, A Renaissance Hotel"',
#        'The Mansion House', 'Setanta Centre', "O'Connell GPO Luas",
#        'Raheny Medical, Centric Health', 'Skincheck',
#        'Baldoyle Rd Junction Bus Station', 'Clontarf Seafront',
#        'The Retail Park Liffey Valley', 'The Grafton Hotel',
#        'Kellys Hotel', "St. Joseph's Centre For The Visually Impaired",
#        'Dublin Bus Stop No 906', 'The Devlin Hotel',
#        'Four Star Pizza Ranelagh', 'Albert college exam hall, DCU.',
#        'Diverse 11', "Olesya's Wine Bar", 'Secret Closet',
#        "O'Shea's Merchant", 'Project Arts Centre',
#        'Temple Bar Cultural Trust', 'Bad Ass Café', 'Boomerang Nightclub',
#        'Trinity Comprehensive School', 'Arnotts Department Store',
#        'Spicy Bite Halal Food', 'The House', 'Cliff Path Loop',
#        'The Wall', 'Thunders Home Bakery', "The Butler's Pantry",
#        'NDLS - An tSeirbhís Náisiúnta um Cheadúnias Tiomana',
#        'Dublin Triumph Ireland', 'DCUBS Postgraduate Computer Room',
#        'Pure Pharmacy', 'Raymar Hair Salon', 'Macari’s Take Away',
#        'Main Passenger Terminal', 'Compass Skyview Hotel',
#        'The Station 1', 'Jamsai Cafe', 'Roti behind Sutthi Temple',
#        'Porridge in front of Phrommet Shrine', 'Sathorn Unique Tower',
#        'Stamford International University', 'Bangkok University',
#        'Future Park', 'Silpakorn University', 'Central Salaya',
#        'KRIRK University', 'Siam Square', 'Sasin School of Management',
#        "Matt Weldon's", 'The Morrison, a DoubleTree by Hilton Hotel',
#        'Clearwater Shopping Centre', 'Beaumont House',
#        "Chan's Chinese Takeaway", 'Far East Chinese Takeaway',
#        'Aviva Stadium', 'Sandymount Hotel', 'Avoca',
#        'TC GREEN Condominium', 'Srinakharinwirot University',
#        'Eastin Thana City Golf  Resort Bangkok',
#        'Thana City Golf & Sports Club',
#        'Chiang Mai International Airport', 'Chiang Mai Chiang Thai House',
#        'Chiangmai Airport Post Office',
#        'Fort of Ka-Tham anmeldelser, Chiang Mai',
#        'Chiang Mai Gate Market', 'Pad Thai 5 flavor',
#        'Chiang Mai University', 'Umong Temple', 'Bougain Fah Place',
#        'One Nimman', 'Bai Orchid and butterfly',
#        'DuO Hairstation Chiangmai', 'The Good View Village',
#        'White Boutique and Spa', 'The UN Irish Pub',
#        'Left Hotel Chiang Mai', 'Super Rich', 'Siamese Nanglinchi',
#        'Kasikorn Bank', 'University College Dublin', 'Permanent TSB',
#        'Adagio Access Nice Acropolis', 'Nfc World Congress',
#        'Station Garibaldi', 'Cafe de Turin',
#        'Aparthotel Adagio Access Nice Acropolis', 'Acropolis', 'Citea',
#        'Restaurant la Tartane', 'Terminal 1', '5Ifty2Wo',
#        'Metro Hotel Dublin Airport',
#        'Howth Junction and Donaghmede Dart Station', 'TRX Dublin',
#        "St Stephen's Green", 'Waltons New School of Music',
#        'The Westbury Hotel', 'Panama bar', 'Garda Boat Club', 'Odeon',
#        'Clare Village', 'Regus - Dublin, Santry', "Suzy's apart.",
#        'Jervis Shopping Centre', 'Clifton Court Hotel',
#        'Embassy of the Republic of Poland in Dublin (Consular Section)',
#        'On 15 bus', 'Collaborative Student Room 11', 'Grafton Street',
#        'Dusk', 'Dublin Bus 41c', 'Whitehall Church', 'Airport Takeaway',
#        'Boyle Sports', 'Hope Brewery', 'Clannad Medical Centre',
#        'The Spire of Dublin', "Kavanagh's Marino House",
#        'Clontarf Veterinary Hospital', 'New Mandarin Chinese Take Away',
#        'Graingers', 'Pure', 'Griffith Hall',
#        'Marino Institute Of Education', 'Google Ireland',
#        '7066-Edenmore Park', "Bewley's Café & Tea Room", 'Dardistown',
#        'Madrid Airport Barajas Adolfo Suárez',
#        'Madrid-Chamartin Railway Station', 'THE CHAMMRIN TERRACE',
#        'Autonomous University of Madrid', 'Chamartin Metro',
#        'Dublin Airport', 'Grange Woodbine Club, Raheny Road',
#        'Red Stables', "Olive's Room", 'Molly Malone Statue',
#        'Joe Duffy Opel', 'The Brew', 'Sillouge', 'Dublin Bus',
#        'The Central Hotel', 'East Point Business Park',
#        'Quickpark at Dublin Airport', 'Copper Alley Bistro',
#        'Il Panorama Cafe', 'Blanchardstown Centre', 'Marks & Spencer',
#        'Blanchardstown Retail Park', 'National Botanic Gardens',
#        'Ned Kelly', 'Athletic Stadium Santry',
#        'Santry Veterinary Surgery', 'The Dog House Howth',
#        'Castleway Apartments', 'Christ Church Cathedral', 'Rosa Madre',
#        'Wall of Fame', 'Xian Street Food', 'The Old Spot', "Woodie's",
#        '17A From Coolock To Blanch Sc', 'LloydsPharmacy',
#        'M50 Truck & Van Centre Mercedes-Benz', 'Hillview B&B',
#        "Supermac's", 'Print Stations', 'Chapelgate',
#        'Kyushoshinjitsu Ju-Jutsu Dojo', 'DID Electrical',
#        'Killester College of Further Education', 'Copsewood Aviaries',
#        'Massimo Dutti', 'Brams Cafe', 'Prada', 'Dublin City Council',
#        'Harding Hotel', "Jury's Coffee Dock", '51St And Green',
#        'Edinburgh Airport (EDI)', 'EDI - Car Rental Village',
#        'Pentland Restaurant, Dalmahoy Marriott Country Club',
#        'Dalmahoy Hotel & Country Club', 'The Inn on the Mile',
#        'Restaurant', 'Edinburgh Castle', 'Duck Bay Hotel & Marina',
#        'Pure Gym - Edinburgh West', "Sainsbury's Petrol Station",
#        "Sainsbury's Cafe", 'Beechwood', 'Ballivor Community Centre',
#        'Munich Airport Terminal 2', 'Munich Airport',
#        'Incheon International Airport', 'Techno World', 'Oryu Okcheonga',
#        'Daejeon Convention Center',
#        'Korea Institute of Science and Technology',
#        "Hwang Ki-soon's Hand Noodles & Pork Cutlet",
#        'Lotte City Hotel Daejeon', 'Golfzon', 'Daejeon Station',
#        'Seoul Station', 'Jung Woo-yeon',
#        'Cheongpyeong Charcoal Fire Ribs',
#        'The Steak House Peer 79 Royal Steak', 'Kim Taehong Restaurant',
#        'Junwoo house', 'Banpodong Playground', 'Gwangjang Market',
#        'The capital Onnuri Pharmacy', 'Hanji Mart', 'Seon Gallery',
#        'Hanok tea house', 'Nagwon Rice Cake House', 'Maple Tree House',
#        'Hamilton Hotel', 'The Fountain', 'Hong Kong Restaurant 0410',
#        'The Rouge Flower', 'Hobnob Hostel', 'Tung Yu Temple', 'Kaber',
#        'Faculty of Science', 'Narit', "The Duke's",
#        'Play Condominium by Malada', 'Imed Pharmacy', 'District Front',
#        'Chiang Mai District Office', 'Bangkok Airways Business Lounge',
#        'FN Outlet Office', 'Citadines Sukhumvit 8 Bangkok',
#        'Khao Hom Restaurant', 'Adelphi Suites', 'Gateway Ekamai',
#        'TOM N TOMS', 'Cafe de Salil restaurant', 'Ka Shing',
#        'Artane Castle', 'Royal Thai Massage Ireland', 'Dentistry.ie',
#        'Parnell Park', 'ALDI', 'Mater Misericordiae University Hospital',
#        'Avoca - Malahide Castle', 'Kilkenny', "Domino's Pizza",
#        'The Bonnington Hotel', 'Michael Edwards Photography',
#        'St Anne’s Farmers Market', 'Hilton Shuttle', 'River Cafe',
#        'Cabury', 'An Post', 'Philipsburgh Avenue', 'Kennedys Foodstore',
#        'Zero One', 'Pizza Hut', 'Halfords', 'Sophie Li Hair Design',
#        "St Mary's Church", 'Q-Park The Spire',
#        'City Studios And Apartments By Thekeycollection.ie',
#        'Meadows & Byrne', 'Town Yard', 'Deer Park Hotel Golf & Spa',
#        'Sutton Dart Station', 'Sam’s Coffee House', 'Perfect Day Café',
#        'Whitehall Colmcille Gaa Club', 'Raheny Dart Station', "McHugh's",
#        'Eurospar', 'Chanel College', 'Topaz', 'Deansgrange Business Park',
#        'Subway', 'Applegreen', "Joe's Village Cafe", '53 Avenue',
#        'Macs Shoe Repairs', 'Windsor Avenue',
#        "St Anne's Park & Rose Gardens",
#        'On The Matthews coach In transit', 'The Pond',
#        'Baldoyle Badminton Centre', 'Dollymount Beach',
#        "McLoughlin's Bar", 'Robertos Pizza & Pasta', 'Offington',
#        'Castlerea Credit Union', 'Bodega Coffee', 'Howth Lighthouse',
#        '14 Bus Stop', "Fisher's Cross", 'Fonthill Business Park',
#        'ABC Picture Framing', 'Burrow Beach', 'Yan (成功)', "Kellogg's IRE",
#        'Cable&Wireless Office', 'Finglas Ford Centre',
#        'Audi North Dublin', "St. Anne's Park",
#        'Crowne Plaza Dublin Airport, an IHG Hotel', 'B&Q',
#        'Q220 - DCU Business School', 'Wren Urban Nest', "Keogh's Cafe",
#        'Crescent House', 'Brigdefield Apartments', 'B&Q Dublin - Swords',
#        'An Garda Síochána', 'Dennings Cars', 'Sandyford View'],
#       dtype=object)

# %%
import pytz
from pysearch.utils.time import hour2part_of_day

# %%
def minute_id_to_datetime(minute_id):
    # 20190101_1037 
    year = int(minute_id[:4])
    month = int(minute_id[4:6])
    day = int(minute_id[6:8])
    hour = int(minute_id[9:11])
    minute = int(minute_id[11:13])
    return datetime(year, month, day, hour, minute)


def datetime_to_ymd(datetime):
    return datetime.strftime("%Y%m%d")

def datetime_to_weekday(datetime):
    return calendar.day_name[datetime.weekday()]

def datetime_to_year(datetime):
    return str(datetime.year)
def datetime_to_month(datetime):
    return str(datetime.month)

def datetime_to_localtime(datetime, tz='Europe/Dublin'):
    if tz is None or tz == '':
        return None
    hour = datetime.astimezone(pytz.timezone(tz)).hour
    return hour

datetime_to_weekday(datetime.now())
# Out:
# 'Monday'

# %%
df['timestamp'] = df['minute_id'].apply(minute_id_to_datetime).apply(datetime_to_ymd)
df['local_time'] = df.apply(lambda x: datetime_to_localtime(minute_id_to_datetime(x['minute_id']), tz=x['new_timezone']), axis=1)
df['weekday'] = df['minute_id'].apply(minute_id_to_datetime).apply(datetime_to_weekday)
df['year'] = df['minute_id'].apply(minute_id_to_datetime).apply(datetime_to_year)
df['month'] = df['minute_id'].apply(minute_id_to_datetime).apply(datetime_to_month)

# %%
df['local_time'].isna().sum()
# Out:
# 54

# %%
# fill nan local_time with previous value
df['local_time'] = df['local_time'].fillna(method='ffill')
df['semantic_time'] = df['local_time'].apply(hour2part_of_day)

# %%
df.drop(columns=['minute_id'], inplace=True)
df.head()
# Out:
#    stop   new_lat  new_lng semantic_name foursquare_id original_name  \
# 0  True  53.38998 -6.14576          HOME
# 1  True  53.38998 -6.14576          HOME
# 2  True  53.38998 -6.14576          HOME
# 3  True  53.38998 -6.14576          HOME
# 4  True  53.38998 -6.14576          HOME
#
#   categories parent movement  movement_prob  ...  \
# 0                     Inside       0.981373  ...
# 1                     Inside       0.997463  ...
# 2                     Inside       0.875969  ...
# 3                     Inside       0.998937  ...
# 4                     Inside       0.756499  ...
#
#                                    Tags OCR  \
# 0                                indoor
# 1            wall,indoor,room,furniture
# 2                       building,window
# 3  indoor,wall,person,counter,cluttered
# 4                           indoor,wall
#
#                                              Caption CaptionScore timestamp  \
# 0                            a window with a curtain     0.367844  20190101
# 1                   a room with a shelf and a mirror     0.277621  20190101
# 2                 a view of a building from a window     0.349112  20190101
# 3                              a person in a kitchen     0.491968  20190101
# 4  a black rectangular object with a white object...      0.33464  20190101
#
#   local_time  weekday  year month semantic_time
# 0       10.0  Tuesday  2019     1       morning
# 1       10.0  Tuesday  2019     1       morning
# 2       10.0  Tuesday  2019     1       morning
# 3       10.0  Tuesday  2019     1       morning
# 4       10.0  Tuesday  2019     1       morning
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Create index in Elasticsearch

# %%
from pysearch.elastic import ElasticProcessor
from pysearch.utils.time import nlp2datetime

# %%
from pprint import pprint
pprint(config)
# Out:
# {'CACHE_DIR': '.cache/',
#  'DIMENSION': 2,
#  'HOST': '0.0.0.0',
#  'INDEX': None,
#  'PASSWORD': '123456',
#  'PORT': '20542',
#  'RETURN_SIZE': 10,
#  'USERNAME': 'elastic'}

# %%
config['INDEX'] = 'lsc23_full_db'
proc = ElasticProcessor(config, max_result_window=1000000)
# Out:
# Connected to Elasticsearch node

# %%
proc.available_indices()
# Out:
# dict_keys(['lsc23_db', 'lsc23_full_db'])

# %%
proc.info()
# Out:
# {'properties': {'Caption': {'type': 'text'},
#   'CaptionScore': {'type': 'text'},
#   'ImageID': {'type': 'text'},
#   'OCR': {'type': 'text'},
#   'Tags': {'type': 'text'},
#   'categories': {'type': 'text'},
#   'city': {'type': 'text'},
#   'country': {'type': 'text'},
#   'foursquare_id': {'type': 'text'},
#   'index': {'type': 'text'},
#   'local_time': {'type': 'float'},
#   'month': {'type': 'text'},
#   'movement': {'type': 'text'},
#   'movement_prob': {'type': 'float'},
#   'new_lat': {'type': 'float'},
#   'new_lng': {'type': 'float'},
#   'new_timezone': {'type': 'text'},
#   'original_name': {'type': 'text'},
#   'parent': {'type': 'text'},
#   'semantic_name': {'type': 'text'},
#   'semantic_time': {'type': 'text'},
#   'stop': {'type': 'boolean'},
#   'timestamp': {'type': 'date', 'format': 'basic_date'},
#   'weekday': {'type': 'text'},
#   'year': {'type': 'text'}}}

# %%
# proc.kill('lsc23_full_db')

# %%
from pandas.io.json import build_table_schema 

def df_schema_to_mapping(df_schema,timefield='date'):
    mapping = {}
    for col in df_schema['fields']:
        col_name = col['name']
        col_type = col['type']
        if col_type == 'string':
            col_type = 'text'
        if col_type == 'number':
            col_type = 'float'
        if col_name == timefield:
            col_type = 'date'
            mapping[col_name] = {
                'type': col_type,
                'format': 'basic_date'
            }
            continue
        mapping[col_name] = {
            'type': col_type
        }
    return mapping

def export_mapping(df):
    df_schema = build_table_schema(df)
    mapping = df_schema_to_mapping(df_schema, timefield='timestamp')
    mapping = {
        "mappings": {
            "properties": mapping
        }
    }
    return mapping

mapping = export_mapping(df)
mapping
# Out:
# {'mappings': {'properties': {'index': {'type': 'text'},
#    'stop': {'type': 'boolean'},
#    'new_lat': {'type': 'float'},
#    'new_lng': {'type': 'float'},
#    'semantic_name': {'type': 'text'},
#    'foursquare_id': {'type': 'text'},
#    'original_name': {'type': 'text'},
#    'categories': {'type': 'text'},
#    'parent': {'type': 'text'},
#    'movement': {'type': 'text'},
#    'movement_prob': {'type': 'float'},
#    'city': {'type': 'text'},
#    'country': {'type': 'text'},
#    'new_timezone': {'type': 'text'},
#    'ImageID': {'type': 'text'},
#    'Tags': {'type': 'text'},
#    'OCR': {'type': 'text'},
#    'Caption': {'type': 'text'},
#    'CaptionScore': {'type': 'text'},
#    'timestamp': {'type': 'date', 'format': 'basic_date'},
#    'local_time': {'type': 'float'},
#    'weekday': {'type': 'text'},
#    'year': {'type': 'text'},
#    'month': {'type': 'text'},
#    'semantic_time': {'type': 'text'}}}}

# %%
proc.index_dataframe(df, mapping)
# Out:
#   0%|          | 0/723329 [00:00<?, ?it/s]
# 100%|██████████| 723329/723329 [01:36<00:00, 7499.59it/s]

# %%
from pprint import pprint 
pprint(proc.info())
# Out:
# {'properties': {'Caption': {'type': 'text'},
#                 'CaptionScore': {'type': 'text'},
#                 'ImageID': {'type': 'text'},
#                 'OCR': {'type': 'text'},
#                 'Tags': {'type': 'text'},
#                 'categories': {'type': 'text'},
#                 'city': {'type': 'text'},
#                 'country': {'type': 'text'},
#                 'foursquare_id': {'type': 'text'},
#                 'index': {'type': 'text'},
#                 'local_time': {'type': 'float'},
#                 'month': {'type': 'text'},
#                 'movement': {'type': 'text'},
#                 'movement_prob': {'type': 'float'},
#                 'new_lat': {'type': 'float'},
#                 'new_lng': {'type': 'float'},
#                 'new_timezone': {'type': 'text'},
#                 'original_name': {'type': 'text'},
#                 'parent': {'type': 'text'},
#                 'semantic_name': {'type': 'text'},
#                 'semantic_time': {'type': 'text'},
#                 'stop': {'type': 'boolean'},
#                 'timestamp': {'format': 'basic_date', 'type': 'date'},
#                 'weekday': {'type': 'text'},
#                 'year': {'type': 'text'}}}

# %%
date = nlp2datetime('12-13-2019')
date
# Out:
# datetime.datetime(2019, 12, 13, 9, 44, 49)

# %%
def check_duplicate_response(responses):
    hits_name = [hit['_id'] for hit in responses]
    assert len(hits_name) == len(set(hits_name)), "Duplicate response"

# %%
proc.get_document_by_id(['20200509_133031_000'])
# Out:
# Function get_document_by_id elapsed time: 0:00:00.031337
# [{'_index': 'lsc23_full_db',
#   '_id': '20200509_133031_000',
#   '_score': 2.0,
#   '_source': {'stop': False,
#    'new_lat': 53.76520193,
#    'new_lng': -8.39711666,
#    'semantic_name': 'Car',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.8909477591514587,
#    'city': 'Roscommon, Ireland, Roscommon Municipal District',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20200509_133031_000.jpg',
#    'Tags': 'tree,outdoor,plant',
#    'OCR': '',
#    'Caption': 'a house with trees around it',
#    'CaptionScore': 0.3369276523590088,
#    'timestamp': '20200509',
#    'local_time': 14.0,
#    'weekday': 'Saturday',
#    'year': '2020',
#    'month': '5',
#    'semantic_time': 'early afternoon'}}]

# %%
check_duplicate_response(proc.compose_pipeline({'text': {'fields': ['month'], 'must': '9', 'should': None }}))
# Out:
# Function run elapsed time: 0:00:00.000005

# %%
check_duplicate_response(proc.search_text_closestday_pipeline('indoor', [], timefield='timestamp', timestamp=date, filter=None))
# Out:
# Function run elapsed time: 0:00:00.000009

# %%
proc.search_text_closestday_pipeline('indoor', [], timefield='timestamp', timestamp=date, filter=None, topk=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 proc.search_text_closestday_pipeline('indoor', [], timefield='timestamp', timestamp=date, filter=None, topk=5)
#
# NameError: name 'date' is not defined

# %%
check_duplicate_response(proc.compose_pipeline({'text': {'fields': ['year'], 'must': '2019', 'should': None }}))
# Out:
# Function run elapsed time: 0:00:00.000004

# %%
ELASTIC_PORT
# Out:
# '20542'

# %%
# es = Elasticsearch([f'http://0.0.0.0:{self.port}'],
#                 timeout=100, \
#                 connection_class=RequestsHttpConnection, 
#                 http_auth=(self.username, self.password), 
#                 use_ssl=False, 
#                 verify_certs=False)

# convert this to curl command

# change max_result_window to 1000000
# !curl -XPUT 'http://0.0.0.0:20542/_all/_settings?preserve_existing=true' -d '{"index.max_result_window" : "1000" }'
# Out:
# {"error":"Content-Type header [application/x-www-form-urlencoded] is not supported","status":406}

# %%
len(proc.compose_pipeline({'text': {'fields': ['year'], 'must': '2019', 'should': None }}, topk=10001))
# Out:
# Function run elapsed time: 0:00:00.000005
# 10001

# %%
proc.compose_pipeline({'text': {'fields': ['month'], 'must': '9', 'should': None }})
# Out:
# Function run elapsed time: 0:00:00.000005
# [{'_index': 'lsc23_full_db',
#   '_id': '20190901_083352_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9903006553649902,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083352_000.jpg',
#    'Tags': 'indoor,wall,bed,bedroom',
#    'OCR': '',
#    'Caption': 'a bed with a white pillow',
#    'CaptionScore': 0.3492282032966614,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083426_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.972182035446167,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083426_000.jpg',
#    'Tags': 'wall,indoor',
#    'OCR': '',
#    'Caption': 'a wall with a picture frame and a lamp on it',
#    'CaptionScore': 0.3219580948352813,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083443_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9973015785217284,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083443_000.jpg',
#    'Tags': 'wall,indoor',
#    'OCR': '',
#    'Caption': 'a room with a desk and a door',
#    'CaptionScore': 0.4456681907176971,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083500_000',
#   '_score': 2.6428761,
#   '_source': {'stop': False,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'Car',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Walking Outside',
#    'movement_prob': 0.4920864701271057,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083500_000.jpg',
#    'Tags': 'outdoor,sky,house',
#    'OCR': '',
#    'Caption': 'a street with cars parked along it',
#    'CaptionScore': 0.4481688737869262,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083517_000',
#   '_score': 2.6428761,
#   '_source': {'stop': False,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'Car',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Car',
#    'movement_prob': 0.9900757670402528,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083517_000.jpg',
#    'Tags': 'person',
#    'OCR': '',
#    'Caption': 'a person holding a cell phone',
#    'CaptionScore': 0.4168724715709686,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083534_000',
#   '_score': 2.6428761,
#   '_source': {'stop': False,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'Car',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.5524464249610901,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083534_000.jpg',
#    'Tags': 'text,car,outdoor,building,road,parked,house,curb,parking,van,roof',
#    'OCR': '06-D-58377',
#    'Caption': 'a car parked in front of a house',
#    'CaptionScore': 0.5465652346611023,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083551_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.99042809009552,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083551_000.jpg',
#    'Tags': 'wall,indoor',
#    'OCR': '',
#    'Caption': 'a fireplace in a room',
#    'CaptionScore': 0.477733701467514,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083608_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9976288676261902,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083608_000.jpg',
#    'Tags': 'wall,indoor,living,ceiling,room,furniture,area',
#    'OCR': '',
#    'Caption': 'a living room with a fireplace',
#    'CaptionScore': 0.4890182316303253,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083625_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.982633411884308,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083625_000.jpg',
#    'Tags': 'kitchen,indoor,food,wall,person,preparing,ceiling,standing,cooking,working,counter,cluttered',
#    'OCR': 'HSTA,MILK',
#    'Caption': 'a person cooking in a kitchen',
#    'CaptionScore': 0.5929048657417297,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190901_083642_000',
#   '_score': 2.6428761,
#   '_source': {'stop': True,
#    'new_lat': 53.3899717,
#    'new_lng': -6.145808,
#    'semantic_name': 'HOME',
#    'foursquare_id': '',
#    'original_name': '',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9422003030776978,
#    'city': 'Dublin, Ireland, Leinster',
#    'country': 'Ireland',
#    'new_timezone': 'Europe/Dublin',
#    'ImageID': '20190901_083642_000.jpg',
#    'Tags': 'indoor,kitchen,man,person,preparing,ceiling,cooking',
#    'OCR': 'SON',
#    'Caption': 'a man cooking in a kitchen',
#    'CaptionScore': 0.5542888045310974,
#    'timestamp': '20190901',
#    'local_time': 9.0,
#    'weekday': 'Sunday',
#    'year': '2019',
#    'month': '9',
#    'semantic_time': 'morning'}}]

# %%
proc.compose_pipeline({'text': {'fields': ['semantic_name', 'OCR', 'Caption', 'country', 'Tags'], 'must': "Zeus Conference", 'should': None }})
# Out:
# Function run elapsed time: 0:00:00.000005
# [{'_index': 'lsc23_full_db',
#   '_id': '20190109_150833_000',
#   '_score': 20.574127,
#   '_source': {'stop': True,
#    'new_lat': 40.6359851,
#    'new_lng': 22.9355687,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.993350088596344,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_150833_000.jpg',
#    'Tags': 'text,indoor,wall,ceiling,screen',
#    'OCR': '',
#    'Caption': 'a few people in a conference room',
#    'CaptionScore': 0.4219984114170074,
#    'timestamp': '20190109',
#    'local_time': 17.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early evening'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190108_121824_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.6359812,
#    'new_lng': 22.9355425,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.8751575350761414,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190108_121824_000.jpg',
#    'Tags': 'text,indoor,laptop,computer,several',
#    'OCR': '',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.4621817767620086,
#    'timestamp': '20190108',
#    'local_time': 14.0,
#    'weekday': 'Tuesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_094601_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.636002,
#    'new_lng': 22.9355738,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.928307294845581,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_094601_000.jpg',
#    'Tags': 'text,person,indoor,people',
#    'OCR': '',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.4842816591262817,
#    'timestamp': '20190109',
#    'local_time': 11.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'late morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_163446_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.63600632,
#    'new_lng': 22.93562118,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.8016670346260071,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_163446_000.jpg',
#    'Tags': 'indoor,person,floor',
#    'OCR': 'Find,sho,walking,ac,down),a,stre,city.',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.5109865665435791,
#    'timestamp': '20190109',
#    'local_time': 18.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early evening'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_083842_000',
#   '_score': 17.556707,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9910867810249328,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_083842_000.jpg',
#    'Tags': 'indoor,cabin,conference room',
#    'OCR': '',
#    'Caption': 'a room with chairs and a projector screen',
#    'CaptionScore': 0.3678921461105346,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_084018_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9952731728553772,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_084018_000.jpg',
#    'Tags': 'indoor,wall,ceiling,conference room',
#    'OCR': 'or,ST,OF,ET,karge,,Tom,Polk,From',
#    'Caption': 'a room with a stage and chairs',
#    'CaptionScore': 0.3059627711772918,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_084226_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9873335361480712,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_084226_000.jpg',
#    'Tags': 'indoor,ceiling,several,conference room',
#    'OCR': '',
#    'Caption': 'a room with blue chairs and a light',
#    'CaptionScore': 0.2920307219028473,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_114758_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6360256,
#    'new_lng': 22.9357525,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9987012147903442,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_114758_000.jpg',
#    'Tags': 'person,laptop,indoor,conference room',
#    'OCR': '',
#    'Caption': 'a group of people sitting in a room with a laptop',
#    'CaptionScore': 0.4425938427448272,
#    'timestamp': '20190109',
#    'local_time': 13.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_131619_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6360438,
#    'new_lng': 22.9357229,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9989681243896484,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_131619_000.jpg',
#    'Tags': 'person,indoor,ceiling,conference room',
#    'OCR': '',
#    'Caption': 'a group of people sitting in a room with a large screen',
#    'CaptionScore': 0.3763365745544433,
#    'timestamp': '20190109',
#    'local_time': 15.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190313_031143_000',
#   '_score': 16.976925,
#   '_source': {'stop': True,
#    'new_lat': 13.73641021,
#    'new_lng': 100.53336191,
#    'semantic_name': 'Chulalongkorn University',
#    'foursquare_id': '4b4213acf964a5205ccc25e3',
#    'original_name': 'Chulalongkorn University (จุฬาลงกรณ์มหาวิทยาลัย)',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9610496163368224,
#    'city': 'Bangkok, Thailand',
#    'country': 'Thailand',
#    'new_timezone': 'Asia/Bangkok',
#    'ImageID': '20190313_031143_000.jpg',
#    'Tags': 'indoor,conference room',
#    'OCR': '',
#    'Caption': 'an empty conference room',
#    'CaptionScore': 0.4703913927078247,
#    'timestamp': '20190313',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '3',
#    'semantic_time': 'morning'}}]

# %%
proc.compose_pipeline({'text': {'fields': ['semantic_name', 'OCR', 'Caption', 'country', 'Tags'], 'must': None, 'should': "Zeus Conference" }})
# Out:
# Function run elapsed time: 0:00:00.000005
# [{'_index': 'lsc23_full_db',
#   '_id': '20190109_150833_000',
#   '_score': 20.574127,
#   '_source': {'stop': True,
#    'new_lat': 40.6359851,
#    'new_lng': 22.9355687,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.993350088596344,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_150833_000.jpg',
#    'Tags': 'text,indoor,wall,ceiling,screen',
#    'OCR': '',
#    'Caption': 'a few people in a conference room',
#    'CaptionScore': 0.4219984114170074,
#    'timestamp': '20190109',
#    'local_time': 17.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early evening'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190108_121824_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.6359812,
#    'new_lng': 22.9355425,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.8751575350761414,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190108_121824_000.jpg',
#    'Tags': 'text,indoor,laptop,computer,several',
#    'OCR': '',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.4621817767620086,
#    'timestamp': '20190108',
#    'local_time': 14.0,
#    'weekday': 'Tuesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_094601_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.636002,
#    'new_lng': 22.9355738,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.928307294845581,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_094601_000.jpg',
#    'Tags': 'text,person,indoor,people',
#    'OCR': '',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.4842816591262817,
#    'timestamp': '20190109',
#    'local_time': 11.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'late morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_163446_000',
#   '_score': 20.095089,
#   '_source': {'stop': True,
#    'new_lat': 40.63600632,
#    'new_lng': 22.93562118,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.8016670346260071,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_163446_000.jpg',
#    'Tags': 'indoor,person,floor',
#    'OCR': 'Find,sho,walking,ac,down),a,stre,city.',
#    'Caption': 'a group of people in a conference room',
#    'CaptionScore': 0.5109865665435791,
#    'timestamp': '20190109',
#    'local_time': 18.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early evening'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_083842_000',
#   '_score': 17.556707,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9910867810249328,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_083842_000.jpg',
#    'Tags': 'indoor,cabin,conference room',
#    'OCR': '',
#    'Caption': 'a room with chairs and a projector screen',
#    'CaptionScore': 0.3678921461105346,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_084018_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9952731728553772,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_084018_000.jpg',
#    'Tags': 'indoor,wall,ceiling,conference room',
#    'OCR': 'or,ST,OF,ET,karge,,Tom,Polk,From',
#    'Caption': 'a room with a stage and chairs',
#    'CaptionScore': 0.3059627711772918,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_084226_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6358994,
#    'new_lng': 22.9355604,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9873335361480712,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_084226_000.jpg',
#    'Tags': 'indoor,ceiling,several,conference room',
#    'OCR': '',
#    'Caption': 'a room with blue chairs and a light',
#    'CaptionScore': 0.2920307219028473,
#    'timestamp': '20190109',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'morning'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_114758_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6360256,
#    'new_lng': 22.9357525,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9987012147903442,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_114758_000.jpg',
#    'Tags': 'person,laptop,indoor,conference room',
#    'OCR': '',
#    'Caption': 'a group of people sitting in a room with a laptop',
#    'CaptionScore': 0.4425938427448272,
#    'timestamp': '20190109',
#    'local_time': 13.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'early afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190109_131619_000',
#   '_score': 17.041845,
#   '_source': {'stop': True,
#    'new_lat': 40.6360438,
#    'new_lng': 22.9357229,
#    'semantic_name': 'Zeus Conference Rooms',
#    'foursquare_id': '5bbd89fffd9d73002cb24fee',
#    'original_name': 'Zeus Conference Rooms',
#    'categories': 'Office',
#    'parent': 'Mediterranean Palace Hotel',
#    'movement': 'Inside',
#    'movement_prob': 0.9989681243896484,
#    'city': 'Thessaloniki Regional Unit, Thessaloniki Municipal Unit, Macedonia and Thrace, Greece',
#    'country': 'Greece',
#    'new_timezone': 'Europe/Athens',
#    'ImageID': '20190109_131619_000.jpg',
#    'Tags': 'person,indoor,ceiling,conference room',
#    'OCR': '',
#    'Caption': 'a group of people sitting in a room with a large screen',
#    'CaptionScore': 0.3763365745544433,
#    'timestamp': '20190109',
#    'local_time': 15.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '1',
#    'semantic_time': 'afternoon'}},
#  {'_index': 'lsc23_full_db',
#   '_id': '20190313_031143_000',
#   '_score': 16.976925,
#   '_source': {'stop': True,
#    'new_lat': 13.73641021,
#    'new_lng': 100.53336191,
#    'semantic_name': 'Chulalongkorn University',
#    'foursquare_id': '4b4213acf964a5205ccc25e3',
#    'original_name': 'Chulalongkorn University (จุฬาลงกรณ์มหาวิทยาลัย)',
#    'categories': '',
#    'parent': '',
#    'movement': 'Inside',
#    'movement_prob': 0.9610496163368224,
#    'city': 'Bangkok, Thailand',
#    'country': 'Thailand',
#    'new_timezone': 'Asia/Bangkok',
#    'ImageID': '20190313_031143_000.jpg',
#    'Tags': 'indoor,conference room',
#    'OCR': '',
#    'Caption': 'an empty conference room',
#    'CaptionScore': 0.4703913927078247,
#    'timestamp': '20190313',
#    'local_time': 10.0,
#    'weekday': 'Wednesday',
#    'year': '2019',
#    'month': '3',
#    'semantic_time': 'morning'}}]
