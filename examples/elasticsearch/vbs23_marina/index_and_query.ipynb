# %%
import requests
import os
from datetime import datetime
from dotenv import load_dotenv
from pathlib import Path
import numpy as np
import pandas as pd 

dotenv_path = Path('.env')
load_dotenv(dotenv_path=dotenv_path)

ELASTIC_PORT = os.environ.get("ELASTIC_PORT", None)
ELASTIC_USERNAME = os.environ.get("ELASTIC_USERNAME", None)
ELASTIC_PASSWORD = os.environ.get("ELASTIC_PASSWORD", None)

assert ELASTIC_PORT is not None, "ELASTIC_PORT is not set"
assert ELASTIC_USERNAME is not None, "ELASTIC_USERNAME is not set"
assert ELASTIC_PASSWORD is not None, "ELASTIC_PASSWORD is not set"

config = {
    # Global config
    "HOST": "0.0.0.0",
    "PORT": ELASTIC_PORT,
    "USERNAME": ELASTIC_USERNAME,
    "PASSWORD": ELASTIC_PASSWORD,
    "INDEX": None,
    "RETURN_SIZE": 10,
    "CACHE_DIR": ".cache/",
    "DIMENSION": 2,
}

# %% [markdown]
# ## Prepapre DB

# %%
import pandas as pd 
from tqdm import tqdm 
df = pd.read_csv('vbs23_meta.csv')

# %%
df.head()
# Out:
#    id location camera_model  \
# 0   1   Dapang   DJI Osmo 3
# 1   2   Dapang   DJI Osmo 3
# 2   3   Dapang   DJI Osmo 3
# 3   4   Dapang   DJI Osmo 3
# 4   5   Dapang   DJI Osmo 3
#
#                                           thumbnails  \
# 0  information/thumbnails/Dapang_Jul2022/0005_000...
# 1  information/thumbnails/Dapang_Jul2022/0005_000...
# 2  information/thumbnails/Dapang_Jul2022/0005_000...
# 3  information/thumbnails/Dapang_Jul2022/0005_000...
# 4  information/thumbnails/Dapang_Jul2022/0005_000...
#
#                                      selected_frames         created_time  \
# 0  information/selected_frames/Dapang_Jul2022/000...  2022:08:27 07:48:37
# 1  information/selected_frames/Dapang_Jul2022/000...  2022:08:27 07:48:37
# 2  information/selected_frames/Dapang_Jul2022/000...  2022:08:27 07:48:37
# 3  information/selected_frames/Dapang_Jul2022/000...  2022:08:27 07:48:37
# 4  information/selected_frames/Dapang_Jul2022/000...  2022:08:27 07:48:37
#
#        date  year   month day_of_week    part_of_day local_time  \
# 0  20220827  2022  August    Saturday  early morning      07:48
# 1  20220827  2022  August    Saturday  early morning      07:48
# 2  20220827  2022  August    Saturday  early morning      07:48
# 3  20220827  2022  August    Saturday  early morning      07:48
# 4  20220827  2022  August    Saturday  early morning      07:48
#
#                                           captions  width  height  ext   fps  \
# 0                 underwater view of a coral reef.   1920    1080  mp4  30.0
# 1  the reef is a bit smaller than the ones we saw.   1920    1080  mp4  30.0
# 2   the reef is a bit more shallow than the beach.   1920    1080  mp4  30.0
# 3                      a small group of fish swim.   1920    1080  mp4  30.0
# 4  a small group of fish swim around a coral reef.   1920    1080  mp4  30.0
#
#                 index
# 0  Dapang_Jul2022_5_1
# 1  Dapang_Jul2022_5_2
# 2  Dapang_Jul2022_5_3
# 3  Dapang_Jul2022_5_4
# 4  Dapang_Jul2022_5_5

# %%
df['index'] = df.id

# %% [markdown]
# ## Create index in Elasticsearch

# %%
from pysearch.elastic import ElasticProcessor
from pysearch.utils.time import nlp2datetime

# %%
config['INDEX'] = 'vbs23_db'
proc = ElasticProcessor(config)
# Out:
# Connected to Elasticsearch node

# %%
proc.available_indices()
# Out:
# dict_keys(['vbs22_db', 'vbs23_db', 'test_index'])

# %%
# proc.kill('vbs22_db')

# %%
df_structure = {  
    "mappings": {
        "properties": {
            'index': {"type": "integer"}, # required for pysearch
            "date": {"type": "date", "format": "basic_date"}, # required for pysearch            
            'id': {"type": "integer"},
            'vimeo_id': {"type": "text"},
            'url': {"type": "text"},
            'title': {"type": "text"},
            'description': {"type": "text"},
            'channel': {"type": "text"},
            'tags': {"type": "text"},
            'categories': {"type": "text"},
            'upload_date': {"type": "text"},
            'year': {"type": "integer"},
            'month': {"type": "text"},
            'day_of_week': {"type": "text"},
            'part_of_day': {"type": "text"},
            'local_time': {"type": "text"},
            'width': {"type": "integer"},
            'height': {"type": "integer"}
        }
    }
}

# %%
df['index'] = df['id'] 
df.head()
proc.index_dataframe(df, df_structure)
# Out:
# 100%|██████████| 43797/43797 [00:04<00:00, 10466.19it/s]

# %%
from pprint import pprint 
pprint(proc.info())
# Out:
# {'properties': {'camera_model': {'fields': {'keyword': {'ignore_above': 256,
#                                                         'type': 'keyword'}},
#                                  'type': 'text'},
#                 'captions': {'fields': {'keyword': {'ignore_above': 256,
#                                                     'type': 'keyword'}},
#                              'type': 'text'},
#                 'categories': {'type': 'text'},
#                 'channel': {'type': 'text'},
#                 'created_time': {'fields': {'keyword': {'ignore_above': 256,
#                                                         'type': 'keyword'}},
#                                  'type': 'text'},
#                 'date': {'format': 'basic_date', 'type': 'date'},
#                 'day_of_week': {'type': 'text'},
#                 'description': {'type': 'text'},
#                 'ext': {'fields': {'keyword': {'ignore_above': 256,
#                                                'type': 'keyword'}},
#                         'type': 'text'},
#                 'fps': {'type': 'float'},
#                 'height': {'type': 'integer'},
#                 'id': {'type': 'integer'},
#                 'index': {'type': 'integer'},
#                 'local_time': {'type': 'text'},
#                 'location': {'fields': {'keyword': {'ignore_above': 256,
#                                                     'type': 'keyword'}},
#                              'type': 'text'},
#                 'month': {'type': 'text'},
#                 'part_of_day': {'type': 'text'},
#                 'selected_frames': {'fields': {'keyword': {'ignore_above': 256,
#                                                            'type': 'keyword'}},
#                                     'type': 'text'},
#                 'tags': {'type': 'text'},
#                 'thumbnails': {'fields': {'keyword': {'ignore_above': 256,
#                                                       'type': 'keyword'}},
#                                'type': 'text'},
#                 'title': {'type': 'text'},
#                 'upload_date': {'type': 'text'},
#                 'url': {'type': 'text'},
#                 'vimeo_id': {'type': 'text'},
#                 'width': {'type': 'integer'},
#                 'year': {'type': 'integer'}}}

# %%
date = nlp2datetime('11/1/2022')
date
# Out:
# datetime.datetime(2022, 11, 1, 5, 54, 10)

# %%
proc.search_text_closestday_pipeline('Swim Tuesday', [], timefield='date', timestamp=date, filter=None)
# Out:
# Function run elapsed time: 0:00:00.000006
# [{'_index': 'vbs23_db',
#   '_id': '212',
#   '_score': 0.0,
#   '_source': {'id': 212,
#    'location': 'Silverstrand',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/Silverstrand_Aug2022/0007_00212.jpg',
#    'selected_frames': 'information/selected_frames/Silverstrand_Aug2022/0007_00212.jpg',
#    'created_time': '2022:08:22 22:56:34',
#    'date': 20220822,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Monday',
#    'part_of_day': 'late afternoon',
#    'local_time': '22:56',
#    'captions': 'a small group of fish swim around a reef.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '240',
#   '_score': 0.0,
#   '_source': {'id': 240,
#    'location': 'Silverstrand',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/Silverstrand_Aug2022/0007_00240.jpg',
#    'selected_frames': 'information/selected_frames/Silverstrand_Aug2022/0007_00240.jpg',
#    'created_time': '2022:08:22 22:56:34',
#    'date': 20220822,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Monday',
#    'part_of_day': 'late afternoon',
#    'local_time': '22:56',
#    'captions': 'the water was so clear that the fish were able to swim underwater.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '250',
#   '_score': 0.0,
#   '_source': {'id': 250,
#    'location': 'Silverstrand',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/Silverstrand_Aug2022/0007_00250.jpg',
#    'selected_frames': 'information/selected_frames/Silverstrand_Aug2022/0007_00250.jpg',
#    'created_time': '2022:08:22 22:56:34',
#    'date': 20220822,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Monday',
#    'part_of_day': 'late afternoon',
#    'local_time': '22:56',
#    'captions': 'a small group of fish swim.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '265',
#   '_score': 0.0,
#   '_source': {'id': 265,
#    'location': 'Silverstrand',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/Silverstrand_Aug2022/0007_00265.jpg',
#    'selected_frames': 'information/selected_frames/Silverstrand_Aug2022/0007_00265.jpg',
#    'created_time': '2022:08:22 22:56:34',
#    'date': 20220822,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Monday',
#    'part_of_day': 'late afternoon',
#    'local_time': '22:56',
#    'captions': 'the water was so clear that the fish were able to swim underwater.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '271',
#   '_score': 0.0,
#   '_source': {'id': 271,
#    'location': 'Silverstrand',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/Silverstrand_Aug2022/0007_00271.jpg',
#    'selected_frames': 'information/selected_frames/Silverstrand_Aug2022/0007_00271.jpg',
#    'created_time': '2022:08:22 22:56:34',
#    'date': 20220822,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Monday',
#    'part_of_day': 'late afternoon',
#    'local_time': '22:56',
#    'captions': 'the water was so clear that the fish were able to swim underwater.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '177',
#   '_score': 0.0,
#   '_source': {'id': 177,
#    'location': 'HongKong',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/HongKong_Jul2021/0002_00177.jpg',
#    'selected_frames': 'information/selected_frames/HongKong_Jul2021/0002_00177.jpg',
#    'created_time': '2022:08:27 03:49:38',
#    'date': 20220827,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Saturday',
#    'part_of_day': 'night',
#    'local_time': '03:49',
#    'captions': 'a large group of fish swim.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '181',
#   '_score': 0.0,
#   '_source': {'id': 181,
#    'location': 'HongKong',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/HongKong_Jul2021/0002_00181.jpg',
#    'selected_frames': 'information/selected_frames/HongKong_Jul2021/0002_00181.jpg',
#    'created_time': '2022:08:27 03:49:38',
#    'date': 20220827,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Saturday',
#    'part_of_day': 'night',
#    'local_time': '03:49',
#    'captions': 'a small group of fish swim around the rocks.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '182',
#   '_score': 0.0,
#   '_source': {'id': 182,
#    'location': 'HongKong',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/HongKong_Jul2021/0002_00182.jpg',
#    'selected_frames': 'information/selected_frames/HongKong_Jul2021/0002_00182.jpg',
#    'created_time': '2022:08:27 03:49:38',
#    'date': 20220827,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Saturday',
#    'part_of_day': 'night',
#    'local_time': '03:49',
#    'captions': 'a small group of fish swim.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '184',
#   '_score': 0.0,
#   '_source': {'id': 184,
#    'location': 'HongKong',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/HongKong_Jul2021/0002_00184.jpg',
#    'selected_frames': 'information/selected_frames/HongKong_Jul2021/0002_00184.jpg',
#    'created_time': '2022:08:27 03:49:38',
#    'date': 20220827,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Saturday',
#    'part_of_day': 'night',
#    'local_time': '03:49',
#    'captions': 'a small group of fish swim.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}},
#  {'_index': 'vbs23_db',
#   '_id': '186',
#   '_score': 0.0,
#   '_source': {'id': 186,
#    'location': 'HongKong',
#    'camera_model': 'HERO10 Black',
#    'thumbnails': 'information/thumbnails/HongKong_Jul2021/0002_00186.jpg',
#    'selected_frames': 'information/selected_frames/HongKong_Jul2021/0002_00186.jpg',
#    'created_time': '2022:08:27 03:49:38',
#    'date': 20220827,
#    'year': 2022,
#    'month': 'August',
#    'day_of_week': 'Saturday',
#    'part_of_day': 'night',
#    'local_time': '03:49',
#    'captions': 'a small group of fish swim around a rock.',
#    'width': 3840,
#    'height': 2160,
#    'ext': 'mp4',
#    'fps': 30.0}}]
